# %% [markdown]
# # Leqi Zhong final project notebook 1

# %% [markdown]
# Summary: My datasets are from https://www.cde.ca.gov/ds/ad/filessp.asp, I'd like to explore California public schools' free meals/free or reduced price meals(FRPM) data in the past 5 years. Specifically, how the data change before and post-pandemic.
#
# In notebook 1, I'll do the following:
# 1. Import datasets
# 2. Remove columns
# 3. Change column names
# 4. Change datatypes

# %% [markdown]
# ## Import datasets

# %%
import pandas as pd

# %%
data_2122 = pd.read_csv('data_2122.csv')
data_2122.head()
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2021-2022            1          10017       130419     Alameda
# 1     2021-2022            1          10017       130401     Alameda
# 2     2021-2022            1          10017       130625     Alameda
# 3     2021-2022            1          10017       137448     Alameda
# 4     2021-2022            1          10017       123968     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0                 Alameda County Community  County Office of Education (COE)
# 1       Alameda County Juvenile Hall/Court  County Office of Education (COE)
# 2                   Alternatives in Action  County Office of Education (COE)
# ...

# %%
data_2021 = pd.read_csv('data_2021.csv')
data_2021.head()
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2020-2021            1          10017       130419     Alameda
# 1     2020-2021            1          10017       130401     Alameda
# 2     2020-2021            1          10017       137448     Alameda
# 3     2020-2021            1          10017       123968     Alameda
# 4     2020-2021            1          10017       136101     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0                 Alameda County Community  County Office of Education (COE)
# 1       Alameda County Juvenile Hall/Court  County Office of Education (COE)
# 2                Aurum Preparatory Academy  County Office of Education (COE)
# ...

# %%
data_1920 = pd.read_csv('data_1920.csv')
data_1920.head()
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2019-2020            1          10017       112607     Alameda
# 1     2019-2020            1          10017       123968     Alameda
# 2     2019-2020            1          10017       124172     Alameda
# 3     2019-2020            1          10017       125567     Alameda
# 4     2019-2020            1          10017       129403     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0   Envision Academy for Arts & Technology  County Office of Education (COE)
# 1  Community School for Creative Education  County Office of Education (COE)
# 2                          Yu Ming Charter  County Office of Education (COE)
# ...

# %%
data_1819 = pd.read_csv('data_1819.csv')
data_1819.head()
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2018-2019            1          10017       112607     Alameda
# 1     2018-2019            1          10017       123968     Alameda
# 2     2018-2019            1          10017       124172     Alameda
# 3     2018-2019            1          10017       125567     Alameda
# 4     2018-2019            1          10017       130401     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0   Envision Academy for Arts & Technology  County Office of Education (COE)
# 1  Community School for Creative Education  County Office of Education (COE)
# 2                          Yu Ming Charter  County Office of Education (COE)
# ...

# %%
data_1718 = pd.read_csv('data_1718.csv')
data_1718.head()
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2017-2018            1          10017       112607     Alameda
# 1     2017-2018            1          10017       123968     Alameda
# 2     2017-2018            1          10017       124172     Alameda
# 3     2017-2018            1          10017       125567     Alameda
# 4     2017-2018            1          10017       130401     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0   Envision Academy for Arts & Technology  County Office of Education (COE)
# 1  Community School for Creative Education  County Office of Education (COE)
# 2                          Yu Ming Charter  County Office of Education (COE)
# ...

# %% [markdown]
# ## Remove columns

# %% [markdown]
# Let's see how many columns does the dataset have:

# %%
data_2122.columns
# Out:
# Index(['Academic Year', 'County Code', 'District Code', 'School Code',
#        'County Name', 'District Name', 'School Name', 'District Type',
#        'School Type', 'Educational \nOption Type', 'NSLP \nProvision \nStatus',
#        'Charter \nSchool \n(Y/N)', 'Charter \nSchool \nNumber',
#        'Charter \nFunding \nType', 'IRC', 'Low Grade', 'High Grade',
#        'Enrollment \n(K-12)', 'Free Meal \nCount \n(K-12)',
#        'Percent (%) \nEligible Free \n(K-12)', 'FRPM Count \n(K-12)',
#        'Percent (%) \nEligible FRPM \n(K-12)', 'Enrollment \n(Ages 5-17)',
#        'Free Meal \nCount \n(Ages 5-17)',
#        'Percent (%) \nEligible Free \n(Ages 5-17)', 'FRPM Count \n(Ages 5-17)',
#        'Percent (%) \nEligible FRPM \n(Ages 5-17)',
#        'CALPADS Fall 1 \nCertification Status'],
#       dtype='object')

# %% [markdown]
# Since "K-12" has more comprehensive data than "age 5-17", I would like to exclude all the 5-17 columns. Also, I would like to exclude "charter" columns because they provide no information when a school doesn't belong to a charter. I'll also remove columns such as district codes, district type, etc.

# %%
data_2122 = data_2122[['Academic Year',
                             'County Name',
                             'District Name',
                             'School Name',
                             'School Type',
                             'Educational \nOption Type',
                             'Low Grade',
                             'High Grade',
                             'Enrollment \n(K-12)',
                             'Free Meal \nCount \n(K-12)',
                             'Percent (%) \nEligible Free \n(K-12)',
                             'FRPM Count \n(K-12)',
                             'Percent (%) \nEligible FRPM \n(K-12)'
                            ]].copy()
data_2122
# Out:
#       Academic Year County Name                       District Name  \
# 0         2021-2022     Alameda  Alameda County Office of Education
# 1         2021-2022     Alameda  Alameda County Office of Education
# 2         2021-2022     Alameda  Alameda County Office of Education
# 3         2021-2022     Alameda  Alameda County Office of Education
# 4         2021-2022     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10553     2021-2022        Yuba                Wheatland Union High
# 10554     2021-2022        Yuba                Wheatland Union High
# 10555     2021-2022        Yuba                Wheatland Union High
# 10556     2021-2022        Yuba                Wheatland Union High
# 10557     2021-2022        Yuba                Wheatland Union High
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %% [markdown]
# Now Let me do the same for other years' datasets

# %%
data_2021 = data_2021[['Academic Year',
                             'County Name',
                             'District Name',
                             'School Name',
                             'School Type',
                             'Educational \nOption Type',
                             'Low Grade',
                             'High Grade',
                             'Enrollment \n(K-12)',
                             'Free Meal \nCount \n(K-12)',
                             'Percent (%) \nEligible Free \n(K-12)',
                             'FRPM Count \n(K-12)',
                             'Percent (%) \nEligible FRPM \n(K-12)'
                            ]].copy()
data_2021
# Out:
#       Academic Year County Name                       District Name  \
# 0         2020-2021     Alameda  Alameda County Office of Education
# 1         2020-2021     Alameda  Alameda County Office of Education
# 2         2020-2021     Alameda  Alameda County Office of Education
# 3         2020-2021     Alameda  Alameda County Office of Education
# 4         2020-2021     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10542     2020-2021        Yuba                Wheatland Union High
# 10543     2020-2021        Yuba                Wheatland Union High
# 10544     2020-2021        Yuba                Wheatland Union High
# 10545     2020-2021      Alpine   Alpine County Office of Education
# 10546     2020-2021      Sierra   Sierra County Office of Education
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %%
data_1920 = data_1920[['Academic Year',
                             'County Name',
                             'District Name',
                             'School Name',
                             'School Type',
                             'Educational \nOption Type',
                             'Low Grade',
                             'High Grade',
                             'Enrollment \n(K-12)',
                             'Free Meal \nCount \n(K-12)',
                             'Percent (%) \nEligible Free \n(K-12)',
                             'FRPM Count \n(K-12)',
                             'Percent (%) \nEligible FRPM \n(K-12)'
                            ]].copy()
data_1920
# Out:
#       Academic Year  County Name                       District Name  \
# 0         2019-2020      Alameda  Alameda County Office of Education
# 1         2019-2020      Alameda  Alameda County Office of Education
# 2         2019-2020      Alameda  Alameda County Office of Education
# 3         2019-2020      Alameda  Alameda County Office of Education
# 4         2019-2020      Alameda  Alameda County Office of Education
# ...             ...          ...                                 ...
# 10587     2019-2020         Yuba                Wheatland Union High
# 10588     2019-2020         Yuba                Wheatland Union High
# 10589     2019-2020  Los Angeles                              Lennox
# 10590     2019-2020       Alpine   Alpine County Office of Education
# 10591     2019-2020       Sierra   Sierra County Office of Education
#
#                                    School Name  \
# 0       Envision Academy for Arts & Technology
# ...

# %%
data_1819 = data_1819[['Academic Year',
                             'County Name',
                             'District Name',
                             'School Name',
                             'School Type',
                             'Educational \nOption Type',
                             'Low Grade',
                             'High Grade',
                             'Enrollment \n(K-12)',
                             'Free Meal \nCount \n(K-12)',
                             'Percent (%) \nEligible Free \n(K-12)',
                             'FRPM Count \n(K-12)',
                             'Percent (%) \nEligible FRPM \n(K-12)'
                            ]].copy()
data_1819
# Out:
#       Academic Year County Name                       District Name  \
# 0         2018-2019     Alameda  Alameda County Office of Education
# 1         2018-2019     Alameda  Alameda County Office of Education
# 2         2018-2019     Alameda  Alameda County Office of Education
# 3         2018-2019     Alameda  Alameda County Office of Education
# 4         2018-2019     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10515     2018-2019        Yuba                           Wheatland
# 10516     2018-2019        Yuba                           Wheatland
# 10517     2018-2019        Yuba                           Wheatland
# 10518     2018-2019        Yuba                Wheatland Union High
# 10519     2018-2019        Yuba                Wheatland Union High
#
#                                    School Name                  School Type  \
# ...

# %%
data_1718 = data_1718[['Academic Year',
                             'County Name',
                             'District Name',
                             'School Name',
                             'School Type',
                             'Educational \nOption Type',
                             'Low Grade',
                             'High Grade',
                             'Enrollment \n(K-12)',
                             'Free Meal \nCount \n(K-12)',
                             'Percent (%) \nEligible Free \n(K-12)',
                             'FRPM Count \n(K-12)',
                             'Percent (%) \nEligible FRPM \n(K-12)'
                            ]].copy()
data_1718
# Out:
#       Academic Year County Name                       District Name  \
# 0         2017-2018     Alameda  Alameda County Office of Education
# 1         2017-2018     Alameda  Alameda County Office of Education
# 2         2017-2018     Alameda  Alameda County Office of Education
# 3         2017-2018     Alameda  Alameda County Office of Education
# 4         2017-2018     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10470     2017-2018        Yuba                           Wheatland
# 10471     2017-2018        Yuba                Wheatland Union High
# 10472     2017-2018        Yuba                Wheatland Union High
# 10473     2017-2018      Sierra   Sierra County Office of Education
# 10474     2017-2018      Alpine   Alpine County Office of Education
#
#                                    School Name                  School Type  \
# ...

# %% [markdown]
# ## Rename columns

# %%
data_2122.rename(columns={'Free Meal \nCount \n(K-12)': '2122_Free_Meal',
                                'Educational \nOption Type': 'Educational_Type',
                                'Enrollment \n(K-12)': '2122_Enrollment',
                                'Free Meal \nCount \n(K-12)': '2122_Free_Meal_Count',
                                'Percent (%) \nEligible Free \n(K-12)': '2122_Free_Meal_Percent',
                                'FRPM Count \n(K-12)': '2122_FRPM_Count',
                                'Percent (%) \nEligible FRPM \n(K-12)': '2122_FRPM_Percent'
                               }, inplace=True)
data_2122
# Out:
#       Academic Year County Name                       District Name  \
# 0         2021-2022     Alameda  Alameda County Office of Education
# 1         2021-2022     Alameda  Alameda County Office of Education
# 2         2021-2022     Alameda  Alameda County Office of Education
# 3         2021-2022     Alameda  Alameda County Office of Education
# 4         2021-2022     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10553     2021-2022        Yuba                Wheatland Union High
# 10554     2021-2022        Yuba                Wheatland Union High
# 10555     2021-2022        Yuba                Wheatland Union High
# 10556     2021-2022        Yuba                Wheatland Union High
# 10557     2021-2022        Yuba                Wheatland Union High
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %%
data_2021.rename(columns={'Free Meal \nCount \n(K-12)': '2021_Free_Meal',
                                'Educational \nOption Type': 'Educational_Type',
                                'Enrollment \n(K-12)': '2021_Enrollment',
                                'Free Meal \nCount \n(K-12)': '2021_Free_Meal_Count',
                                'Percent (%) \nEligible Free \n(K-12)': '2021_Free_Meal_Percent',
                                'FRPM Count \n(K-12)': '2021_FRPM_Count',
                                'Percent (%) \nEligible FRPM \n(K-12)': '2021_FRPM_Percent'
                               }, inplace=True)
data_2021
# Out:
#       Academic Year County Name                       District Name  \
# 0         2020-2021     Alameda  Alameda County Office of Education
# 1         2020-2021     Alameda  Alameda County Office of Education
# 2         2020-2021     Alameda  Alameda County Office of Education
# 3         2020-2021     Alameda  Alameda County Office of Education
# 4         2020-2021     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10542     2020-2021        Yuba                Wheatland Union High
# 10543     2020-2021        Yuba                Wheatland Union High
# 10544     2020-2021        Yuba                Wheatland Union High
# 10545     2020-2021      Alpine   Alpine County Office of Education
# 10546     2020-2021      Sierra   Sierra County Office of Education
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %%
data_1920.rename(columns={'Free Meal \nCount \n(K-12)': '1920_Free_Meal',
                                'Educational \nOption Type': 'Educational_Type',
                                'Enrollment \n(K-12)': '1920_Enrollment',
                                'Free Meal \nCount \n(K-12)': '1920_Free_Meal_Count',
                                'Percent (%) \nEligible Free \n(K-12)': '1920_Free_Meal_Percent',
                                'FRPM Count \n(K-12)': '1920_FRPM_Count',
                                'Percent (%) \nEligible FRPM \n(K-12)': '1920_FRPM_Percent'
                               }, inplace=True)
data_1920
# Out:
#       Academic Year  County Name                       District Name  \
# 0         2019-2020      Alameda  Alameda County Office of Education
# 1         2019-2020      Alameda  Alameda County Office of Education
# 2         2019-2020      Alameda  Alameda County Office of Education
# 3         2019-2020      Alameda  Alameda County Office of Education
# 4         2019-2020      Alameda  Alameda County Office of Education
# ...             ...          ...                                 ...
# 10587     2019-2020         Yuba                Wheatland Union High
# 10588     2019-2020         Yuba                Wheatland Union High
# 10589     2019-2020  Los Angeles                              Lennox
# 10590     2019-2020       Alpine   Alpine County Office of Education
# 10591     2019-2020       Sierra   Sierra County Office of Education
#
#                                    School Name  \
# 0       Envision Academy for Arts & Technology
# ...

# %%
data_1819.rename(columns={'Free Meal \nCount \n(K-12)': '1819_Free_Meal',
                                'Educational \nOption Type': 'Educational_Type',
                                'Enrollment \n(K-12)': '1819_Enrollment',
                                'Free Meal \nCount \n(K-12)': '1819_Free_Meal_Count',
                                'Percent (%) \nEligible Free \n(K-12)': '1819_Free_Meal_Percent',
                                'FRPM Count \n(K-12)': '1819_FRPM_Count',
                                'Percent (%) \nEligible FRPM \n(K-12)': '1819_FRPM_Percent'
                               }, inplace=True)
data_1819
# Out:
#       Academic Year County Name                       District Name  \
# 0         2018-2019     Alameda  Alameda County Office of Education
# 1         2018-2019     Alameda  Alameda County Office of Education
# 2         2018-2019     Alameda  Alameda County Office of Education
# 3         2018-2019     Alameda  Alameda County Office of Education
# 4         2018-2019     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10515     2018-2019        Yuba                           Wheatland
# 10516     2018-2019        Yuba                           Wheatland
# 10517     2018-2019        Yuba                           Wheatland
# 10518     2018-2019        Yuba                Wheatland Union High
# 10519     2018-2019        Yuba                Wheatland Union High
#
#                                    School Name                  School Type  \
# ...

# %%
data_1718.rename(columns={'Free Meal \nCount \n(K-12)': '1718_Free_Meal',
                                'Educational \nOption Type': 'Educational_Type',
                                'Enrollment \n(K-12)': '1718_Enrollment',
                                'Free Meal \nCount \n(K-12)': '1718_Free_Meal_Count',
                                'Percent (%) \nEligible Free \n(K-12)': '1718_Free_Meal_Percent',
                                'FRPM Count \n(K-12)': '1718_FRPM_Count',
                                'Percent (%) \nEligible FRPM \n(K-12)': '1718_FRPM_Percent'
                               }, inplace=True)
data_1718
# Out:
#       Academic Year County Name                       District Name  \
# 0         2017-2018     Alameda  Alameda County Office of Education
# 1         2017-2018     Alameda  Alameda County Office of Education
# 2         2017-2018     Alameda  Alameda County Office of Education
# 3         2017-2018     Alameda  Alameda County Office of Education
# 4         2017-2018     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10470     2017-2018        Yuba                           Wheatland
# 10471     2017-2018        Yuba                Wheatland Union High
# 10472     2017-2018        Yuba                Wheatland Union High
# 10473     2017-2018      Sierra   Sierra County Office of Education
# 10474     2017-2018      Alpine   Alpine County Office of Education
#
#                                    School Name                  School Type  \
# ...

# %% [markdown]
# ## Change datatype

# %%
data_2122_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10558 entries, 0 to 10557
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Academic Year                       10558 non-null  object
#  1   County Name                         10558 non-null  object
#  2   District Name                       10558 non-null  object
#  3   School Name                         10558 non-null  object
#  4   School Type                         9992 non-null   object
#  5   Educational
# Option Type            9994 non-null   object
#  6   Low Grade                           10135 non-null  object
#  7   High Grade                          10135 non-null  object
#  8   Enrollment
# (K-12)                  10558 non-null  object
#  9   Free Meal
# Count
# (K-12)            10558 non-null  object
#  10  Percent (%)
# Eligible Free
# (K-12)  10558 non-null  object
#  11  FRPM Count
# ...

# %% [markdown]
# Since all columns are in the object format, we need to change them to the number format to do further calculation. Additionally, for columns involving the percentage, we need to change it to float format.

# %% [markdown]
# Method 1:

# %%
data_2122['2122_Free_Meal_Percent'] = data_2122['2122_Free_Meal_Percent'].str.replace('%', '', regex=False)

# %%
data_2122['2122_Free_Meal_Percent'] = pd.to_numeric(data_2122['2122_Free_Meal_Percent'])

# %%
data_2122['2122_Free_Meal_Percent'] = data_2122['2122_Free_Meal_Percent'] / 100

# %%
data_2122
# Out:
#       Academic Year County Name                       District Name  \
# 0         2021-2022     Alameda  Alameda County Office of Education
# 1         2021-2022     Alameda  Alameda County Office of Education
# 2         2021-2022     Alameda  Alameda County Office of Education
# 3         2021-2022     Alameda  Alameda County Office of Education
# 4         2021-2022     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10553     2021-2022        Yuba                Wheatland Union High
# 10554     2021-2022        Yuba                Wheatland Union High
# 10555     2021-2022        Yuba                Wheatland Union High
# 10556     2021-2022        Yuba                Wheatland Union High
# 10557     2021-2022        Yuba                Wheatland Union High
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %% [markdown]
# Method 2:

# %%
data_2122['2122_FRPM_Percent'] = data_2122['2122_FRPM_Percent'].str.strip('%').astype(float)/100
data_2122
# Out:
#       Academic Year County Name                       District Name  \
# 0         2021-2022     Alameda  Alameda County Office of Education
# 1         2021-2022     Alameda  Alameda County Office of Education
# 2         2021-2022     Alameda  Alameda County Office of Education
# 3         2021-2022     Alameda  Alameda County Office of Education
# 4         2021-2022     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10553     2021-2022        Yuba                Wheatland Union High
# 10554     2021-2022        Yuba                Wheatland Union High
# 10555     2021-2022        Yuba                Wheatland Union High
# 10556     2021-2022        Yuba                Wheatland Union High
# 10557     2021-2022        Yuba                Wheatland Union High
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %%
# data_2122_clean['Free_Meal_Count'] = pd.to_numeric(data_2122_clean['Free_Meal_Count'])

# %% [markdown]
# However, when I tried to transfer "free meal count" into number format as above, an error popped up saying it wasn't able to identify the "comma" in numbers. So I have to delete the comma in numbers.

# %%
data_2122['2122_Free_Meal_Count'] = data_2122['2122_Free_Meal_Count'].str.replace(',', '', regex=False)

# %%
data_2122['2122_Free_Meal_Count'] = pd.to_numeric(data_2122['2122_Free_Meal_Count'])

# %%
data_2122.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10558 entries, 0 to 10557
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic Year           10558 non-null  object
#  1   County Name             10558 non-null  object
#  2   District Name           10558 non-null  object
#  3   School Name             10558 non-null  object
#  4   School Type             9992 non-null   object
#  5   Educational_Type        9994 non-null   object
#  6   Low Grade               10135 non-null  object
#  7   High Grade              10135 non-null  object
#  8   2122_Enrollment         10558 non-null  object
#  9   2122_Free_Meal_Count    10558 non-null  int64
#  10  2122_Free_Meal_Percent  10558 non-null  float64
#  11  2122_FRPM_Count         10558 non-null  object
#  12  2122_FRPM_Percent       10558 non-null  float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# It works!! Let's do it for the rest columns.

# %%
data_2122['2122_Enrollment'] = data_2122['2122_Enrollment'].str.replace(',', '', regex=False)
data_2122['2122_Enrollment'] = pd.to_numeric(data_2122['2122_Enrollment'])
data_2122['2122_FRPM_Count'] = data_2122['2122_FRPM_Count'].str.replace(',', '', regex=False)
data_2122['2122_FRPM_Count'] = pd.to_numeric(data_2122['2122_FRPM_Count'])
data_2122.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10558 entries, 0 to 10557
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic Year           10558 non-null  object
#  1   County Name             10558 non-null  object
#  2   District Name           10558 non-null  object
#  3   School Name             10558 non-null  object
#  4   School Type             9992 non-null   object
#  5   Educational_Type        9994 non-null   object
#  6   Low Grade               10135 non-null  object
#  7   High Grade              10135 non-null  object
#  8   2122_Enrollment         10558 non-null  int64
#  9   2122_Free_Meal_Count    10558 non-null  int64
#  10  2122_Free_Meal_Percent  10558 non-null  float64
#  11  2122_FRPM_Count         10558 non-null  int64
#  12  2122_FRPM_Percent       10558 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.0+ MB

# %% [markdown]
# Looks fine. Now I'm going to process the same for the other datasets.

# %%
data_2021['2021_Free_Meal_Percent'] = data_2021['2021_Free_Meal_Percent'].str.strip('%').astype(float)/100
data_2021['2021_FRPM_Percent'] = data_2021['2021_FRPM_Percent'].str.strip('%').astype(float)/100
data_2021
# Out:
#       Academic Year County Name                       District Name  \
# 0         2020-2021     Alameda  Alameda County Office of Education
# 1         2020-2021     Alameda  Alameda County Office of Education
# 2         2020-2021     Alameda  Alameda County Office of Education
# 3         2020-2021     Alameda  Alameda County Office of Education
# 4         2020-2021     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10542     2020-2021        Yuba                Wheatland Union High
# 10543     2020-2021        Yuba                Wheatland Union High
# 10544     2020-2021        Yuba                Wheatland Union High
# 10545     2020-2021      Alpine   Alpine County Office of Education
# 10546     2020-2021      Sierra   Sierra County Office of Education
#
#                                    School Name  \
# 0                     Alameda County Community
# 1           Alameda County Juvenile Hall/Court
# ...

# %%
data_2021['2021_Free_Meal_Count'] = data_2021['2021_Free_Meal_Count'].str.replace(',', '', regex=False)
data_2021['2021_Free_Meal_Count'] = pd.to_numeric(data_2021['2021_Free_Meal_Count'])
data_2021['2021_Enrollment'] = data_2021['2021_Enrollment'].str.replace(',', '', regex=False)
data_2021['2021_Enrollment'] = pd.to_numeric(data_2021['2021_Enrollment'])
data_2021['2021_FRPM_Count'] = data_2021['2021_FRPM_Count'].str.replace(',', '', regex=False)
data_2021['2021_FRPM_Count'] = pd.to_numeric(data_2021['2021_FRPM_Count'])
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10547 entries, 0 to 10546
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic Year           10547 non-null  object
#  1   County Name             10547 non-null  object
#  2   District Name           10547 non-null  object
#  3   School Name             10547 non-null  object
#  4   School Type             10006 non-null  object
#  5   Educational_Type        10006 non-null  object
#  6   Low Grade               10116 non-null  object
#  7   High Grade              10116 non-null  object
#  8   2021_Enrollment         10547 non-null  int64
#  9   2021_Free_Meal_Count    10547 non-null  int64
#  10  2021_Free_Meal_Percent  10547 non-null  float64
#  11  2021_FRPM_Count         10547 non-null  int64
#  12  2021_FRPM_Percent       10547 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.0+ MB

# %%
data_1920['1920_Free_Meal_Percent'] = data_1920['1920_Free_Meal_Percent'].str.strip('%').astype(float)/100
data_1920['1920_FRPM_Percent'] = data_1920['1920_FRPM_Percent'].str.strip('%').astype(float)/100
data_1920
# Out:
#       Academic Year  County Name                       District Name  \
# 0         2019-2020      Alameda  Alameda County Office of Education
# 1         2019-2020      Alameda  Alameda County Office of Education
# 2         2019-2020      Alameda  Alameda County Office of Education
# 3         2019-2020      Alameda  Alameda County Office of Education
# 4         2019-2020      Alameda  Alameda County Office of Education
# ...             ...          ...                                 ...
# 10587     2019-2020         Yuba                Wheatland Union High
# 10588     2019-2020         Yuba                Wheatland Union High
# 10589     2019-2020  Los Angeles                              Lennox
# 10590     2019-2020       Alpine   Alpine County Office of Education
# 10591     2019-2020       Sierra   Sierra County Office of Education
#
#                                    School Name  \
# 0       Envision Academy for Arts & Technology
# ...

# %%
data_1920['1920_Free_Meal_Count'] = data_1920['1920_Free_Meal_Count'].str.replace(',', '', regex=False)
data_1920['1920_Free_Meal_Count'] = pd.to_numeric(data_1920['1920_Free_Meal_Count'])
data_1920['1920_Enrollment'] = data_1920['1920_Enrollment'].str.replace(',', '', regex=False)
data_1920['1920_Enrollment'] = pd.to_numeric(data_1920['1920_Enrollment'])
data_1920['1920_FRPM_Count'] = data_1920['1920_FRPM_Count'].str.replace(',', '', regex=False)
data_1920['1920_FRPM_Count'] = pd.to_numeric(data_1920['1920_FRPM_Count'])
data_1920.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10592 entries, 0 to 10591
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic Year           10592 non-null  object
#  1   County Name             10592 non-null  object
#  2   District Name           10592 non-null  object
#  3   School Name             10592 non-null  object
#  4   School Type             10044 non-null  object
#  5   Educational_Type        10044 non-null  object
#  6   Low Grade               10148 non-null  object
#  7   High Grade              10148 non-null  object
#  8   1920_Enrollment         10592 non-null  int64
#  9   1920_Free_Meal_Count    10592 non-null  int64
#  10  1920_Free_Meal_Percent  10592 non-null  float64
#  11  1920_FRPM_Count         10592 non-null  int64
#  12  1920_FRPM_Percent       10592 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.1+ MB

# %%
data_1819['1819_Free_Meal_Percent'] = data_1819['1819_Free_Meal_Percent'].str.strip('%').astype(float)/100
data_1819['1819_FRPM_Percent'] = data_1819['1819_FRPM_Percent'].str.strip('%').astype(float)/100
data_1819
# Out:
#       Academic Year County Name                       District Name  \
# 0         2018-2019     Alameda  Alameda County Office of Education
# 1         2018-2019     Alameda  Alameda County Office of Education
# 2         2018-2019     Alameda  Alameda County Office of Education
# 3         2018-2019     Alameda  Alameda County Office of Education
# 4         2018-2019     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10515     2018-2019        Yuba                           Wheatland
# 10516     2018-2019        Yuba                           Wheatland
# 10517     2018-2019        Yuba                           Wheatland
# 10518     2018-2019        Yuba                Wheatland Union High
# 10519     2018-2019        Yuba                Wheatland Union High
#
#                                    School Name                  School Type  \
# ...

# %%
data_1819['1819_Free_Meal_Count'] = data_1819['1819_Free_Meal_Count'].str.replace(',', '', regex=False)
data_1819['1819_Free_Meal_Count'] = pd.to_numeric(data_1819['1819_Free_Meal_Count'])
data_1819['1819_Enrollment'] = data_1819['1819_Enrollment'].str.replace(',', '', regex=False)
data_1819['1819_Enrollment'] = pd.to_numeric(data_1819['1819_Enrollment'])
data_1819['1819_FRPM_Count'] = data_1819['1819_FRPM_Count'].str.replace(',', '', regex=False)
data_1819['1819_FRPM_Count'] = pd.to_numeric(data_1819['1819_FRPM_Count'])
data_1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10520 entries, 0 to 10519
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic Year           10520 non-null  object
#  1   County Name             10520 non-null  object
#  2   District Name           10520 non-null  object
#  3   School Name             10520 non-null  object
#  4   School Type             10070 non-null  object
#  5   Educational_Type        10070 non-null  object
#  6   Low Grade               10130 non-null  object
#  7   High Grade              10130 non-null  object
#  8   1819_Enrollment         10520 non-null  int64
#  9   1819_Free_Meal_Count    10520 non-null  int64
#  10  1819_Free_Meal_Percent  10520 non-null  float64
#  11  1819_FRPM_Count         10520 non-null  int64
#  12  1819_FRPM_Percent       10520 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.0+ MB

# %%
data_1718['1718_Free_Meal_Percent'] = data_1718['1718_Free_Meal_Percent'].str.strip('%').astype(float)/100
data_1718['1718_FRPM_Percent'] = data_1718['1718_FRPM_Percent'].str.strip('%').astype(float)/100
data_1718
# Out:
#       Academic Year County Name                       District Name  \
# 0         2017-2018     Alameda  Alameda County Office of Education
# 1         2017-2018     Alameda  Alameda County Office of Education
# 2         2017-2018     Alameda  Alameda County Office of Education
# 3         2017-2018     Alameda  Alameda County Office of Education
# 4         2017-2018     Alameda  Alameda County Office of Education
# ...             ...         ...                                 ...
# 10470     2017-2018        Yuba                           Wheatland
# 10471     2017-2018        Yuba                Wheatland Union High
# 10472     2017-2018        Yuba                Wheatland Union High
# 10473     2017-2018      Sierra   Sierra County Office of Education
# 10474     2017-2018      Alpine   Alpine County Office of Education
#
#                                    School Name                  School Type  \
# ...

# %%
data_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10475 entries, 0 to 10474
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Academic Year           10475 non-null  object
#  1   County Name             10475 non-null  object
#  2   District Name           10475 non-null  object
#  3   School Name             10475 non-null  object
#  4   School Type             10035 non-null  object
#  5   Educational_Type        10035 non-null  object
#  6   Low Grade               10083 non-null  object
#  7   High Grade              10083 non-null  object
#  8   1718_Enrollment         10475 non-null  int64
#  9   1718_Free_Meal_Count    10475 non-null  int64
#  10  1718_Free_Meal_Percent  10475 non-null  float64
#  11  1718_FRPM_Count         10475 non-null  int64
#  12  1718_FRPM_Percent       10475 non-null  float64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Export notebooks

# %%
data_1718.to_csv('data_1718_clean.csv', index=False)

# %%
data_1819.to_csv('data_1819_clean.csv', index=False)

# %%
data_1920.to_csv('data_1920_clean.csv', index=False)

# %%
data_2021.to_csv('data_2021_clean.csv', index=False)

# %%
data_2122.to_csv('data_2122_clean.csv', index=False)
